# %%
import pandas as pd

df = pd.read_csv('data/wine-reviews/winemag-data-130k-v2.csv', index_col='wine_id')
df.head(2)
# Out:
#           country                                        description  \
# wine_id
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1        Portugal  This is ripe and fruity, a wine that is smooth...
#
#           designation  points  price           province region_1 region_2  \
# wine_id
# 0        Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1            Avidagos      87   15.0              Douro      NaN      NaN
#
#            taster_name taster_twitter_handle  \
# wine_id
# 0        Kerin O’Keefe          @kerinokeefe
# 1           Roger Voss            @vossroger
#
#                                                  title         variety  \
# wine_id
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                       winery
# wine_id
# 0                    Nicosia
# 1        Quinta dos Avidagos

# %% [markdown]
# # **Aggregating Data**

# %% [markdown]
# ## Groupby
# To group information by a certain column we can use the `groupby` method of DataFrames.
#
# What you get back is a `DataFrameGroupBy` object, which you can use in the following ways:
# - run one or more aggregation function (e.g. sum, mean, ..), which can be custom made
# - loop over it, therefore working on each partial DataFrame for each group

# %%
df_by_country = df.groupby('country')

df_by_country

# %%
average_points_by_country = df_by_country['points'].mean()

average_points_by_country.head()
# Out:
# country
# Argentina                 86.710263
# Armenia                   87.500000
# Australia                 88.580507
# Austria                   90.101345
# Bosnia and Herzegovina    86.500000
# Name: points, dtype: float64

# %% [markdown]
# looping over the `DataFrameGroupBy` allows access to the sub-dataframes containing data for the subgroups alone, which can be useful for complex, non-standard operations.

# %%
for group, group_df in df.groupby('country'):
    print(f'The average points for {group:<25} = {group_df["points"].mean():.2f}')
# Out:
# The average points for Argentina                 = 86.71
# The average points for Armenia                   = 87.50
# The average points for Australia                 = 88.58
# The average points for Austria                   = 90.10
# The average points for Bosnia and Herzegovina    = 86.50
# The average points for Brazil                    = 84.67
# The average points for Bulgaria                  = 87.94
# The average points for Canada                    = 89.37
# The average points for Chile                     = 86.49
# The average points for China                     = 89.00
# The average points for Croatia                   = 87.22
# The average points for Cyprus                    = 87.18
# The average points for Czech Republic            = 87.25
# The average points for Egypt                     = 84.00
# The average points for England                   = 91.58
# The average points for France                    = 88.85
# The average points for Georgia                   = 87.69
# The average points for Germany                   = 89.85
# The average points for Greece                    = 87.28
# The average points for Hungary                   = 89.19
# The average points for India                     = 90.22
# The average points for Israel                    = 88.47
# The average points for Italy                     = 88.56
# The average points for Lebanon                   = 87.69
# The average points for Luxembourg                = 88.67
# The average points for Macedonia                 = 86.83
# The average points for Mexico                    = 85.26
# The average points for Moldova                   = 87.20
# The average points for Morocco                   = 88.57
# The average points for New Zealand               = 88.30
# The average points for Peru                      = 83.56
# The average points for Portugal                  = 88.25
# The average points for Romania                   = 86.40
# The average points for Serbia                    = 87.50
# The average points for Slovakia                  = 87.00
# The average points for Slovenia                  = 88.07
# The average points for South Africa              = 88.06
# The average points for Spain                     = 87.29
# The average points for Switzerland               = 88.57
# The average points for Turkey                    = 88.09
# The average points for US                        = 88.56
# The average points for Ukraine                   = 84.07
# The average points for Uruguay                   = 86.75

# %% [markdown]
# ### Multi-column grouping
# The grouping can be done over multiple columns, producing a MultiIndexed result

# %%
df_by_country_and_variety = df.groupby(['country', 'variety'])   # multi-dimention groupby

count_of_points = df_by_country_and_variety['points'].count()

count_of_points.head()
# Out:
# country    variety
# Argentina  Barbera                         1
#            Bonarda                       105
#            Bordeaux-style Red Blend       89
#            Bordeaux-style White Blend      1
#            Cabernet Blend                  8
# Name: points, dtype: int64

# %% [markdown]
# To avoid generating a multi-index, the resulting index can be moved to columns instead using the `as_index=False` option

# %%
df.groupby(['country', 'variety'], as_index=False)['points'].count()
# Out:
#         country                            variety  points
# 0     Argentina                            Barbera       1
# 1     Argentina                            Bonarda     105
# 2     Argentina           Bordeaux-style Red Blend      89
# 3     Argentina         Bordeaux-style White Blend       1
# 4     Argentina                     Cabernet Blend       8
# 5     Argentina                     Cabernet Franc      64
# 6     Argentina  Cabernet Franc-Cabernet Sauvignon       3
# 7     Argentina              Cabernet Franc-Malbec       4
# 8     Argentina                 Cabernet Sauvignon     540
# 9     Argentina  Cabernet Sauvignon-Cabernet Franc       1
# 10    Argentina          Cabernet Sauvignon-Malbec      12
# 11    Argentina          Cabernet Sauvignon-Merlot       5
# 12    Argentina          Cabernet Sauvignon-Shiraz       3
# 13    Argentina           Cabernet Sauvignon-Syrah       2
# 14    Argentina                    Cabernet-Malbec       1
# 15    Argentina                     Cabernet-Syrah       1
# 16    Argentina                    Champagne Blend       8
# 17    Argentina                         Chardonnay     295
# 18    Argentina               Chardonnay-Sauvignon       2
# 19    Argentina                Chardonnay-Semillon       1
# 20    Argentina                Chardonnay-Viognier       6
# 21    Argentina                       Chenin Blanc       2
# 22    Argentina            Chenin Blanc-Chardonnay       5
# 23    Argentina                     Gewürztraminer       1
# 24    Argentina                             Malbec    1510
# 25    Argentina                       Malbec Blend       2
# 26    Argentina                     Malbec-Bonarda       5
# 27    Argentina                    Malbec-Cabernet       3
# 28    Argentina              Malbec-Cabernet Franc      10
# 29    Argentina          Malbec-Cabernet Sauvignon      56
# ...         ...                                ...     ...
# 1582         US                 Viognier-Valdiguié       1
# 1583         US                        White Blend     640
# 1584         US                         White Port       1
# 1585         US                     White Riesling      12
# 1586         US                          Zinfandel    2711
# 1587         US                           Zweigelt       7
# 1588    Ukraine                           Bastardo       1
# 1589    Ukraine                 Cabernet Sauvignon       1
# 1590    Ukraine                         Chardonnay       1
# 1591    Ukraine                             Merlot       2
# 1592    Ukraine                     Muscat Hamburg       1
# 1593    Ukraine                           Riesling       1
# 1594    Ukraine                               Rosé       1
# 1595    Ukraine                    Sparkling Blend       6
# 1596    Uruguay                           Albariño       6
# 1597    Uruguay                     Cabernet Franc       2
# 1598    Uruguay                 Cabernet Sauvignon       2
# 1599    Uruguay                         Chardonnay       3
# 1600    Uruguay                             Malbec       2
# 1601    Uruguay                             Merlot       1
# 1602    Uruguay                         Pinot Noir       5
# 1603    Uruguay                          Red Blend      20
# 1604    Uruguay                               Rosé       3
# 1605    Uruguay                    Sauvignon Blanc       1
# 1606    Uruguay                             Tannat      53
# 1607    Uruguay              Tannat-Cabernet Franc       2
# 1608    Uruguay                      Tannat-Merlot       6
# 1609    Uruguay                       Tannat-Syrah       1
# 1610    Uruguay                 Tempranillo-Tannat       1
# 1611    Uruguay                        White Blend       1
#
# [1612 rows x 3 columns]

# %% [markdown]
# ### Applying a custom function to the groupby object
# To apply a custom function to each group we can simply use the `apply` method

# %%
def quantile_ratio(x):
    return x.quantile(0.9)/x.quantile(0.5)

df.groupby('country')['points'].apply(quantile_ratio).head()
# Out:
# country
# Argentina                 1.045977
# Armenia                   1.004571
# Australia                 1.033708
# Austria                   1.033333
# Bosnia and Herzegovina    1.013873
# Name: points, dtype: float64

# %% [markdown]
# ### Performing Multiple Aggregation
# In order to perform more than one aggregation we can use the `.agg` method of the `DataFrameGroupBy`

# %%
df.groupby('country')['price'].agg(['min', 'mean', 'max']).head()
# Out:
#                          min       mean     max
# country
# Argentina                4.0  24.510117   230.0
# Armenia                 14.0  14.500000    15.0
# Australia                5.0  35.437663   850.0
# Austria                  7.0  30.762772  1100.0
# Bosnia and Herzegovina  12.0  12.500000    13.0

# %% [markdown]
# ### ***EXERCISE 5.1***
# Find the tasters that have:
# - reviewed most wine countries
# - spent the most money in wine
#
# **HINT**: to count the unique values in a Series you can use the method `nunique`

# %%
# insert solution here

# %% [markdown]
# ### ***EXERCISE 5.2***
# Find the most controversial wine variety

# %%
# insert solution here

# %% [markdown]
# ### ***EXERCISE 5.3***
# Show the maximum point given by each taster for each region2

# %%
# insert solution here

# %% [markdown]
# ## Pivot Table
# The `pivot_table` method of DataFrame allows to create a table by defining:
# - what to have as rows (index)
# - what to have as columns (columns)
# - what column values to put in the table body (values)
# - what aggregation to use when multiple values end in the same cell (aggfunc)
#
# index and columns can be lists of columns resulting in MultiIndex

# %%
df.pivot_table(index='region_2', columns='points', values='price', aggfunc='mean')
# Out:
# points                   80         81         82         83         84   \
# region_2
# California Other   16.321429  12.222222  12.737327  12.248848  13.138889
# Central Coast      22.000000  23.514706  25.246862  23.364407  25.166994
# Central Valley     17.550000  15.105263  16.666667  16.219512  17.095745
# Columbia Valley    19.000000  16.384615  21.490196  22.229167  20.494048
# Finger Lakes       22.800000  17.636364  16.869565  16.666667  19.198020
# Long Island        18.500000  16.500000  18.916667  14.565217  21.093023
# Napa               25.333333  31.500000  29.604938  32.265487  35.335714
# Napa-Sonoma        30.000000  33.000000  26.200000  24.956522  33.425926
# New York Other           NaN  11.750000  10.500000  22.307692  18.777778
# North Coast        13.000000  15.000000  18.200000  17.000000  18.323529
# Oregon Other       14.000000  26.600000  37.666667  17.357143  19.150000
# Sierra Foothills   19.833333  24.461538  22.555556  21.585366  22.285714
# Sonoma             26.153846  27.321429  25.845070  28.447205  27.390929
# South Coast        30.200000  44.500000  34.833333  36.444444  32.357143
# Southern Oregon    21.000000  18.200000  27.653846  23.205882  24.775000
# Washington Other         NaN  12.000000  14.500000  12.000000  12.833333
# Willamette Valley  11.000000  22.166667  20.916667  21.710526  24.021739
#
# points                   85         86         87         88         89   ...  \
# region_2                                                                  ...
# California Other   13.678756  14.116402  16.073955  18.079832  19.992908  ...
# Central Coast      26.119632  28.676402  28.469810  31.997717  33.101279  ...
# Central Valley     18.326733  17.340000  18.993377  19.103175  21.971963  ...
# Columbia Valley    21.328467  21.767123  24.818731  27.369184  31.256018  ...
# Finger Lakes       18.244240  18.976285  19.830645  20.627660  20.862069  ...
# Long Island        28.000000  25.777778  28.180328  31.990909  29.622222  ...
# Napa               36.593472  41.406489  41.734577  48.731126  51.040462  ...
# Napa-Sonoma        28.815789  33.419048  32.038217  35.419847  37.353846  ...
# New York Other     18.416667  19.250000  23.000000  23.740741  22.058824  ...
# North Coast        20.680000  22.800000  24.791667  25.573529  28.320000  ...
# Oregon Other       21.000000  20.676056  23.904762  22.456693  24.447761  ...
# Sierra Foothills   23.272727  23.283582  23.819209  25.050251  26.637427  ...
# Sonoma             29.559783  31.685254  32.383562  35.185915  39.000000  ...
# South Coast        46.066667  39.800000  38.935484  41.121212  37.969697  ...
# Southern Oregon    24.479167  27.056075  27.025641  24.698630  27.582418  ...
# Washington Other   16.709091  19.448980  18.852459  21.924731  25.267857  ...
# Willamette Valley  25.515625  29.054054  30.799451  31.483516  37.755844  ...
#
# points                   91         92         93          94          95   \
# region_2
# California Other   29.021739  37.116279  53.052632   56.300000   48.333333
# Central Coast      40.884547  44.461411  48.696833   55.383292   58.247934
# Central Valley     22.063492  26.354839  25.666667   27.333333         NaN
# Columbia Valley    39.749776  44.203077  50.575676   56.937173   64.184211
# Finger Lakes       29.041667  31.952381  35.454545   35.833333         NaN
# Long Island        36.923077  47.823529  53.166667   40.000000         NaN
# Napa               64.878613  71.388418  83.209924  106.647059  115.912791
# Napa-Sonoma        42.821705  54.693069  57.600000   65.282051   72.916667
# New York Other     35.000000        NaN        NaN         NaN         NaN
# North Coast        35.488372  45.371429  46.764706   79.941176  112.500000
# Oregon Other       34.044118  43.826087  65.300000   69.142857   64.727273
# Sierra Foothills   30.048000  32.808333  35.551020   48.526316   45.428571
# Sonoma             43.901549  47.746898  52.908800   61.397959   62.294479
# South Coast        48.827586  61.150000  52.500000  120.000000         NaN
# Southern Oregon    29.672131  33.828571  38.666667   48.800000         NaN
# Washington Other   36.828571  46.850000  57.538462   57.250000   87.000000
# Willamette Valley  41.934737  50.099757  58.930000   64.535211   63.813953
#
# points                    96          97          98     99     100
# region_2
# California Other    75.000000   75.000000         NaN    NaN    NaN
# Central Coast       75.727273   82.000000         NaN    NaN    NaN
# Central Valley            NaN         NaN         NaN    NaN    NaN
# Columbia Valley     79.729730   84.750000   94.285714  125.0   80.0
# Finger Lakes              NaN         NaN         NaN    NaN    NaN
# Long Island               NaN         NaN         NaN    NaN    NaN
# Napa               141.232143  172.777778  208.214286  202.5  200.0
# Napa-Sonoma         61.000000  100.000000         NaN    NaN    NaN
# New York Other            NaN         NaN         NaN    NaN    NaN
# North Coast        115.600000  175.000000  120.000000    NaN    NaN
# Oregon Other       113.000000   85.000000   75.000000   75.0    NaN
# Sierra Foothills    69.000000   35.000000         NaN    NaN    NaN
# Sonoma              81.527273  109.500000  137.250000   71.0  450.0
# South Coast               NaN         NaN         NaN    NaN    NaN
# Southern Oregon           NaN         NaN         NaN    NaN    NaN
# Washington Other    44.000000  140.000000         NaN    NaN    NaN
# Willamette Valley   69.411765         NaN         NaN    NaN    NaN
#
# [17 rows x 21 columns]

# %% [markdown]
# # **Reshaping Data**
# Before or after an aggregation it can be useful to sort data by either values of index.

# %%
sorted_by_wine_names = df.sort_values('variety')
sorted_by_wine_names.head(3)
# Out:
#         country                                        description  \
# wine_id
# 98235    France  Abouriou is a grape found almost exclusively i...
# 129894   France  Despite its proximity to Bordeaux, the Marmand...
# 45401        US  Comprised 100% of this rare variety, this wine...
#
#               designation  points  price          province  \
# wine_id
# 98235                Just      87   15.0  Southwest France
# 129894                NaN      91   15.0  Southwest France
# 45401    Moonlight Sonata      85   75.0        California
#
#                      region_1 region_2     taster_name taster_twitter_handle  \
# wine_id
# 98235     Côtes du Marmandais      NaN      Roger Voss            @vossroger
# 129894    Côtes du Marmandais      NaN      Roger Voss            @vossroger
# 45401    Russian River Valley   Sonoma  Virginie Boone               @vboone
#
#                                                      title   variety  \
# wine_id
# 98235    Cave du Marmandais 2012 Just Abouriou (Côtes d...  Abouriou
# 129894   Lionel Osmin & Cie 2014 Abouriou (Côtes du Mar...  Abouriou
# 45401    Cerridwen 2012 Moonlight Sonata Abouriou (Russ...  Abouriou
#
#                      winery
# wine_id
# 98235    Cave du Marmandais
# 129894   Lionel Osmin & Cie
# 45401             Cerridwen

# %%
sorted_by_index_again = sorted_by_wine_names.sort_index()
sorted_by_index_again.head(3)
# Out:
#           country                                        description  \
# wine_id
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1        Portugal  This is ripe and fruity, a wine that is smooth...
# 2              US  Tart and snappy, the flavors of lime flesh and...
#
#           designation  points  price           province           region_1  \
# wine_id
# 0        Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1            Avidagos      87   15.0              Douro                NaN
# 2                 NaN      87   14.0             Oregon  Willamette Valley
#
#                   region_2    taster_name taster_twitter_handle  \
# wine_id
# 0                      NaN  Kerin O’Keefe          @kerinokeefe
# 1                      NaN     Roger Voss            @vossroger
# 2        Willamette Valley   Paul Gregutt           @paulgwine
#
#                                                  title         variety  \
# wine_id
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2        Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                       winery
# wine_id
# 0                    Nicosia
# 1        Quinta dos Avidagos
# 2                  Rainstorm

# %% [markdown]
# By default the sorting is done in ascending way, which can be reversed by using the `ascending=False` option.

# %%
mean_points_per_country = df.groupby('country')['points'].mean()
mean_points_per_country.sort_values(ascending=False)
# Out:
# country
# England                   91.581081
# India                     90.222222
# Austria                   90.101345
# Germany                   89.851732
# Canada                    89.369650
# Hungary                   89.191781
# China                     89.000000
# France                    88.845109
# Luxembourg                88.666667
# Australia                 88.580507
# Morocco                   88.571429
# Switzerland               88.571429
# US                        88.563720
# Italy                     88.562231
# Israel                    88.471287
# New Zealand               88.303030
# Portugal                  88.250220
# Turkey                    88.088889
# Slovenia                  88.068966
# South Africa              88.056388
# Bulgaria                  87.936170
# Georgia                   87.686047
# Lebanon                   87.685714
# Armenia                   87.500000
# Serbia                    87.500000
# Spain                     87.288337
# Greece                    87.283262
# Czech Republic            87.250000
# Croatia                   87.219178
# Moldova                   87.203390
# Cyprus                    87.181818
# Slovakia                  87.000000
# Macedonia                 86.833333
# Uruguay                   86.752294
# Argentina                 86.710263
# Bosnia and Herzegovina    86.500000
# Chile                     86.493515
# Romania                   86.400000
# Mexico                    85.257143
# Brazil                    84.673077
# Ukraine                   84.071429
# Egypt                     84.000000
# Peru                      83.562500
# Name: points, dtype: float64

# %% [markdown]
# ### Sorting by multiple columns
# sorting by multiple columns can be done by passing a list of the columns on which to sort by

# %%
df.sort_values(['points', 'price']).head()
# Out:
#            country                                        description  \
# wine_id
# 23437    Argentina  Candied plum and red berry aromas smell like r...
# 125826   Argentina  While this smells floral and candied, the pala...
# 34501        Chile  Neutral aromas, sour apple and citrus flavors,...
# 81390        Spain  Very light, even thin, this white lacks the st...
# 99996        Chile  The nose is sulphuric and a bit barnyardy, whi...
#
#                  designation  points  price          province   region_1  \
# wine_id
# 23437         Estate Bottled      80    5.0  Mendoza Province    Mendoza
# 125826                   NaN      80    5.0  Mendoza Province    Mendoza
# 34501                    NaN      80    6.0     Curicó Valley        NaN
# 81390    Mediterranean White      80    6.0         Catalonia  Catalonia
# 99996                 Estate      80    6.0      Maipo Valley        NaN
#
#         region_2        taster_name taster_twitter_handle  \
# wine_id
# 23437        NaN  Michael Schachner           @wineschach
# 125826       NaN  Michael Schachner           @wineschach
# 34501        NaN  Michael Schachner           @wineschach
# 81390        NaN                NaN                   NaN
# 99996        NaN  Michael Schachner           @wineschach
#
#                                                      title      variety  \
# wine_id
# 23437        Terrenal 2013 Estate Bottled Malbec (Mendoza)       Malbec
# 125826                 Toca Diamonte 2010 Malbec (Mendoza)       Malbec
# 34501               Quasar 2009 Chardonnay (Curicó Valley)   Chardonnay
# 81390    René Barbier NV Mediterranean White White (Cat...  White Blend
# 99996    Santa Alicia 2001 Estate Chardonnay (Maipo Val...   Chardonnay
#
#                 winery
# wine_id
# 23437         Terrenal
# 125826   Toca Diamonte
# 34501           Quasar
# 81390     René Barbier
# 99996     Santa Alicia

# %% [markdown]
# ## Stack and Unstack
# The `.stack()` and `.unstack()` methods are used to move columns to indecies and viceversa.
#
# This can be handy to convert multi-index Series to more convenient DataFrames. `level` option can be use to select which layer of the MultiIndex to move.

# %%
count_by_country_and_variety = df.groupby(['country', 'variety'])['points'].count()
count_by_country_and_variety.head()
# Out:
# country    variety
# Argentina  Barbera                         1
#            Bonarda                       105
#            Bordeaux-style Red Blend       89
#            Bordeaux-style White Blend      1
#            Cabernet Blend                  8
# Name: points, dtype: int64

# %%
count_by_country_and_variety.unstack(level=0)
# Out:
# country                            Argentina  Armenia  Australia  Austria  \
# variety
# Barbera                                  1.0      NaN        NaN      NaN
# Bonarda                                105.0      NaN        NaN      NaN
# Bordeaux-style Red Blend                89.0      NaN       29.0      2.0
# Bordeaux-style White Blend               1.0      NaN        NaN      NaN
# Cabernet Blend                           8.0      NaN        3.0      NaN
# Cabernet Franc                          64.0      NaN        NaN      1.0
# Cabernet Franc-Cabernet Sauvignon        3.0      NaN        NaN      NaN
# Cabernet Franc-Malbec                    4.0      NaN        NaN      NaN
# Cabernet Sauvignon                     540.0      NaN      266.0      5.0
# Cabernet Sauvignon-Cabernet Franc        1.0      NaN        NaN      NaN
# Cabernet Sauvignon-Malbec               12.0      NaN        NaN      NaN
# Cabernet Sauvignon-Merlot                5.0      NaN       11.0      NaN
# Cabernet Sauvignon-Shiraz                3.0      NaN       11.0      NaN
# Cabernet Sauvignon-Syrah                 2.0      NaN        NaN      NaN
# Cabernet-Malbec                          1.0      NaN        NaN      NaN
# Cabernet-Syrah                           1.0      NaN        NaN      NaN
# Champagne Blend                          8.0      NaN        8.0      1.0
# Chardonnay                             295.0      NaN      400.0     63.0
# Chardonnay-Sauvignon                     2.0      NaN        NaN      NaN
# Chardonnay-Semillon                      1.0      NaN        3.0      NaN
# Chardonnay-Viognier                      6.0      NaN        NaN      NaN
# Chenin Blanc                             2.0      NaN        1.0      NaN
# Chenin Blanc-Chardonnay                  5.0      NaN        NaN      NaN
# Gewürztraminer                           1.0      NaN        NaN      3.0
# Malbec                                1510.0      NaN        5.0      NaN
# Malbec Blend                             2.0      NaN        NaN      NaN
# Malbec-Bonarda                           5.0      NaN        NaN      NaN
# Malbec-Cabernet                          3.0      NaN        NaN      NaN
# Malbec-Cabernet Franc                   10.0      NaN        NaN      NaN
# Malbec-Cabernet Sauvignon               56.0      NaN        NaN      NaN
# ...                                      ...      ...        ...      ...
# Pinot Gris-Gewürztraminer                NaN      NaN        NaN      NaN
# Pinot-Chardonnay                         NaN      NaN        NaN      NaN
# Piquepoul Blanc                          NaN      NaN        NaN      NaN
# Riesling-Chardonnay                      NaN      NaN        NaN      NaN
# Roussanne-Grenache Blanc                 NaN      NaN        NaN      NaN
# Roussanne-Viognier                       NaN      NaN        NaN      NaN
# Sangiovese Cabernet                      NaN      NaN        NaN      NaN
# Sangiovese-Cabernet Sauvignon            NaN      NaN        NaN      NaN
# Sangiovese-Syrah                         NaN      NaN        NaN      NaN
# Sauvignon Musqué                         NaN      NaN        NaN      NaN
# Seyval Blanc                             NaN      NaN        NaN      NaN
# Siegerrebe                               NaN      NaN        NaN      NaN
# Souzao                                   NaN      NaN        NaN      NaN
# St. Vincent                              NaN      NaN        NaN      NaN
# Symphony                                 NaN      NaN        NaN      NaN
# Syrah-Grenache-Viognier                  NaN      NaN        NaN      NaN
# Syrah-Petite Sirah                       NaN      NaN        NaN      NaN
# Tinta Amarela                            NaN      NaN        NaN      NaN
# Tinta Madeira                            NaN      NaN        NaN      NaN
# Touriga                                  NaN      NaN        NaN      NaN
# Traminette                               NaN      NaN        NaN      NaN
# Trousseau Gris                           NaN      NaN        NaN      NaN
# Ugni Blanc                               NaN      NaN        NaN      NaN
# Valdiguié                                NaN      NaN        NaN      NaN
# Valvin Muscat                            NaN      NaN        NaN      NaN
# Vignoles                                 NaN      NaN        NaN      NaN
# Viognier-Gewürztraminer                  NaN      NaN        NaN      NaN
# Viognier-Roussanne                       NaN      NaN        NaN      NaN
# Viognier-Valdiguié                       NaN      NaN        NaN      NaN
# Tempranillo-Tannat                       NaN      NaN        NaN      NaN
#
# country                            Bosnia and Herzegovina  Brazil  Bulgaria  \
# variety
# Barbera                                               NaN     NaN       NaN
# Bonarda                                               NaN     NaN       NaN
# Bordeaux-style Red Blend                              NaN     2.0       2.0
# Bordeaux-style White Blend                            NaN     NaN       NaN
# Cabernet Blend                                        NaN     NaN       NaN
# Cabernet Franc                                        NaN     1.0       2.0
# Cabernet Franc-Cabernet Sauvignon                     NaN     NaN       NaN
# Cabernet Franc-Malbec                                 NaN     NaN       NaN
# Cabernet Sauvignon                                    NaN     4.0      20.0
# Cabernet Sauvignon-Cabernet Franc                     NaN     NaN       NaN
# Cabernet Sauvignon-Malbec                             NaN     NaN       NaN
# Cabernet Sauvignon-Merlot                             NaN     1.0       NaN
# Cabernet Sauvignon-Shiraz                             NaN     NaN       NaN
# Cabernet Sauvignon-Syrah                              NaN     NaN       1.0
# Cabernet-Malbec                                       NaN     NaN       NaN
# Cabernet-Syrah                                        NaN     NaN       NaN
# Champagne Blend                                       NaN     5.0       NaN
# Chardonnay                                            NaN     5.0      16.0
# Chardonnay-Sauvignon                                  NaN     NaN       NaN
# Chardonnay-Semillon                                   NaN     NaN       NaN
# Chardonnay-Viognier                                   NaN     NaN       NaN
# Chenin Blanc                                          NaN     NaN       NaN
# Chenin Blanc-Chardonnay                               NaN     NaN       NaN
# Gewürztraminer                                        NaN     NaN       NaN
# Malbec                                                NaN     NaN       1.0
# Malbec Blend                                          NaN     NaN       NaN
# Malbec-Bonarda                                        NaN     NaN       NaN
# Malbec-Cabernet                                       NaN     NaN       NaN
# Malbec-Cabernet Franc                                 NaN     NaN       NaN
# Malbec-Cabernet Sauvignon                             NaN     NaN       NaN
# ...                                                   ...     ...       ...
# Pinot Gris-Gewürztraminer                             NaN     NaN       NaN
# Pinot-Chardonnay                                      NaN     NaN       NaN
# Piquepoul Blanc                                       NaN     NaN       NaN
# Riesling-Chardonnay                                   NaN     NaN       NaN
# Roussanne-Grenache Blanc                              NaN     NaN       NaN
# Roussanne-Viognier                                    NaN     NaN       NaN
# Sangiovese Cabernet                                   NaN     NaN       NaN
# Sangiovese-Cabernet Sauvignon                         NaN     NaN       NaN
# Sangiovese-Syrah                                      NaN     NaN       NaN
# Sauvignon Musqué                                      NaN     NaN       NaN
# Seyval Blanc                                          NaN     NaN       NaN
# Siegerrebe                                            NaN     NaN       NaN
# Souzao                                                NaN     NaN       NaN
# St. Vincent                                           NaN     NaN       NaN
# Symphony                                              NaN     NaN       NaN
# Syrah-Grenache-Viognier                               NaN     NaN       NaN
# Syrah-Petite Sirah                                    NaN     NaN       NaN
# Tinta Amarela                                         NaN     NaN       NaN
# Tinta Madeira                                         NaN     NaN       NaN
# Touriga                                               NaN     NaN       NaN
# Traminette                                            NaN     NaN       NaN
# Trousseau Gris                                        NaN     NaN       NaN
# Ugni Blanc                                            NaN     NaN       NaN
# Valdiguié                                             NaN     NaN       NaN
# Valvin Muscat                                         NaN     NaN       NaN
# Vignoles                                              NaN     NaN       NaN
# Viognier-Gewürztraminer                               NaN     NaN       NaN
# Viognier-Roussanne                                    NaN     NaN       NaN
# Viognier-Valdiguié                                    NaN     NaN       NaN
# Tempranillo-Tannat                                    NaN     NaN       NaN
#
# country                            Canada  Chile  China  ...  Serbia  \
# variety                                                  ...
# Barbera                               NaN    NaN    NaN  ...     NaN
# Bonarda                               NaN    NaN    NaN  ...     NaN
# Bordeaux-style Red Blend             15.0   37.0    NaN  ...     NaN
# Bordeaux-style White Blend            NaN    NaN    NaN  ...     NaN
# Cabernet Blend                        NaN   28.0    1.0  ...     NaN
# Cabernet Franc                       24.0   38.0    NaN  ...     NaN
# Cabernet Franc-Cabernet Sauvignon     NaN    NaN    NaN  ...     NaN
# Cabernet Franc-Malbec                 NaN    NaN    NaN  ...     NaN
# Cabernet Sauvignon                    7.0  771.0    NaN  ...     NaN
# Cabernet Sauvignon-Cabernet Franc     NaN    5.0    NaN  ...     NaN
# Cabernet Sauvignon-Malbec             NaN    3.0    NaN  ...     NaN
# Cabernet Sauvignon-Merlot             NaN   20.0    NaN  ...     NaN
# Cabernet Sauvignon-Shiraz             NaN    NaN    NaN  ...     NaN
# Cabernet Sauvignon-Syrah              1.0   24.0    NaN  ...     NaN
# Cabernet-Malbec                       NaN    NaN    NaN  ...     NaN
# Cabernet-Syrah                        NaN    NaN    NaN  ...     NaN
# Champagne Blend                       NaN    3.0    NaN  ...     NaN
# Chardonnay                           26.0  516.0    NaN  ...     NaN
# Chardonnay-Sauvignon                  NaN    NaN    NaN  ...     NaN
# Chardonnay-Semillon                   NaN    NaN    NaN  ...     NaN
# Chardonnay-Viognier                   NaN    6.0    NaN  ...     NaN
# Chenin Blanc                          1.0    NaN    NaN  ...     NaN
# Chenin Blanc-Chardonnay               NaN    NaN    NaN  ...     NaN
# Gewürztraminer                       10.0   20.0    NaN  ...     NaN
# Malbec                                1.0  142.0    NaN  ...     NaN
# Malbec Blend                          NaN    NaN    NaN  ...     NaN
# Malbec-Bonarda                        NaN    NaN    NaN  ...     NaN
# Malbec-Cabernet                       NaN    NaN    NaN  ...     NaN
# Malbec-Cabernet Franc                 NaN    NaN    NaN  ...     NaN
# Malbec-Cabernet Sauvignon             NaN    1.0    NaN  ...     NaN
# ...                                   ...    ...    ...  ...     ...
# Pinot Gris-Gewürztraminer             NaN    NaN    NaN  ...     NaN
# Pinot-Chardonnay                      NaN    NaN    NaN  ...     NaN
# Piquepoul Blanc                       NaN    NaN    NaN  ...     NaN
# Riesling-Chardonnay                   NaN    NaN    NaN  ...     NaN
# Roussanne-Grenache Blanc              NaN    NaN    NaN  ...     NaN
# Roussanne-Viognier                    NaN    NaN    NaN  ...     NaN
# Sangiovese Cabernet                   NaN    NaN    NaN  ...     NaN
# Sangiovese-Cabernet Sauvignon         NaN    NaN    NaN  ...     NaN
# Sangiovese-Syrah                      NaN    NaN    NaN  ...     NaN
# Sauvignon Musqué                      NaN    NaN    NaN  ...     NaN
# Seyval Blanc                          NaN    NaN    NaN  ...     NaN
# Siegerrebe                            NaN    NaN    NaN  ...     NaN
# Souzao                                NaN    NaN    NaN  ...     NaN
# St. Vincent                           NaN    NaN    NaN  ...     NaN
# Symphony                              NaN    NaN    NaN  ...     NaN
# Syrah-Grenache-Viognier               NaN    NaN    NaN  ...     NaN
# Syrah-Petite Sirah                    NaN    NaN    NaN  ...     NaN
# Tinta Amarela                         NaN    NaN    NaN  ...     NaN
# Tinta Madeira                         NaN    NaN    NaN  ...     NaN
# Touriga                               NaN    NaN    NaN  ...     NaN
# Traminette                            NaN    NaN    NaN  ...     NaN
# Trousseau Gris                        NaN    NaN    NaN  ...     NaN
# Ugni Blanc                            NaN    NaN    NaN  ...     NaN
# Valdiguié                             NaN    NaN    NaN  ...     NaN
# Valvin Muscat                         NaN    NaN    NaN  ...     NaN
# Vignoles                              NaN    NaN    NaN  ...     NaN
# Viognier-Gewürztraminer               NaN    NaN    NaN  ...     NaN
# Viognier-Roussanne                    NaN    NaN    NaN  ...     NaN
# Viognier-Valdiguié                    NaN    NaN    NaN  ...     NaN
# Tempranillo-Tannat                    NaN    NaN    NaN  ...     NaN
#
# country                            Slovakia  Slovenia  South Africa  Spain  \
# variety
# Barbera                                 NaN       NaN           NaN    NaN
# Bonarda                                 NaN       NaN           NaN    NaN
# Bordeaux-style Red Blend                NaN       4.0          89.0    9.0
# Bordeaux-style White Blend              NaN       NaN           2.0    NaN
# Cabernet Blend                          NaN       NaN           2.0    5.0
# Cabernet Franc                          NaN       1.0           3.0    1.0
# Cabernet Franc-Cabernet Sauvignon       NaN       NaN           NaN    NaN
# Cabernet Franc-Malbec                   NaN       NaN           NaN    NaN
# Cabernet Sauvignon                      NaN       3.0         132.0   53.0
# Cabernet Sauvignon-Cabernet Franc       NaN       NaN           1.0    1.0
# Cabernet Sauvignon-Malbec               NaN       NaN           NaN    NaN
# Cabernet Sauvignon-Merlot               NaN       1.0          10.0    9.0
# Cabernet Sauvignon-Shiraz               NaN       NaN           4.0    1.0
# Cabernet Sauvignon-Syrah                NaN       NaN           NaN    3.0
# Cabernet-Malbec                         NaN       NaN           NaN    NaN
# Cabernet-Syrah                          NaN       NaN           NaN    NaN
# Champagne Blend                         NaN       NaN           5.0   13.0
# Chardonnay                              NaN       4.0         168.0   74.0
# Chardonnay-Sauvignon                    NaN       NaN           NaN    NaN
# Chardonnay-Semillon                     NaN       NaN           NaN    NaN
# Chardonnay-Viognier                     NaN       NaN           1.0    NaN
# Chenin Blanc                            NaN       NaN         181.0    NaN
# Chenin Blanc-Chardonnay                 NaN       NaN           NaN    NaN
# Gewürztraminer                          NaN       NaN           1.0    NaN
# Malbec                                  NaN       NaN           NaN    NaN
# Malbec Blend                            NaN       NaN           NaN    NaN
# Malbec-Bonarda                          NaN       NaN           NaN    NaN
# Malbec-Cabernet                         NaN       NaN           NaN    NaN
# Malbec-Cabernet Franc                   NaN       NaN           NaN    NaN
# Malbec-Cabernet Sauvignon               NaN       NaN           NaN    NaN
# ...                                     ...       ...           ...    ...
# Pinot Gris-Gewürztraminer               NaN       NaN           NaN    NaN
# Pinot-Chardonnay                        NaN       NaN           NaN    NaN
# Piquepoul Blanc                         NaN       NaN           NaN    NaN
# Riesling-Chardonnay                     NaN       NaN           NaN    NaN
# Roussanne-Grenache Blanc                NaN       NaN           NaN    NaN
# Roussanne-Viognier                      NaN       NaN           NaN    NaN
# Sangiovese Cabernet                     NaN       NaN           NaN    NaN
# Sangiovese-Cabernet Sauvignon           NaN       NaN           NaN    NaN
# Sangiovese-Syrah                        NaN       NaN           NaN    NaN
# Sauvignon Musqué                        NaN       NaN           NaN    NaN
# Seyval Blanc                            NaN       NaN           NaN    NaN
# Siegerrebe                              NaN       NaN           NaN    NaN
# Souzao                                  NaN       NaN           NaN    NaN
# St. Vincent                             NaN       NaN           NaN    NaN
# Symphony                                NaN       NaN           NaN    NaN
# Syrah-Grenache-Viognier                 NaN       NaN           NaN    NaN
# Syrah-Petite Sirah                      NaN       NaN           NaN    NaN
# Tinta Amarela                           NaN       NaN           NaN    NaN
# Tinta Madeira                           NaN       NaN           NaN    NaN
# Touriga                                 NaN       NaN           NaN    NaN
# Traminette                              NaN       NaN           NaN    NaN
# Trousseau Gris                          NaN       NaN           NaN    NaN
# Ugni Blanc                              NaN       NaN           NaN    NaN
# Valdiguié                               NaN       NaN           NaN    NaN
# Valvin Muscat                           NaN       NaN           NaN    NaN
# Vignoles                                NaN       NaN           NaN    NaN
# Viognier-Gewürztraminer                 NaN       NaN           NaN    NaN
# Viognier-Roussanne                      NaN       NaN           NaN    NaN
# Viognier-Valdiguié                      NaN       NaN           NaN    NaN
# Tempranillo-Tannat                      NaN       NaN           NaN    NaN
#
# country                            Switzerland  Turkey      US  Ukraine  \
# variety
# Barbera                                    NaN     NaN   238.0      NaN
# Bonarda                                    NaN     NaN     NaN      NaN
# Bordeaux-style Red Blend                   NaN     3.0  1824.0      NaN
# Bordeaux-style White Blend                 NaN     NaN    42.0      NaN
# Cabernet Blend                             NaN     NaN    21.0      NaN
# Cabernet Franc                             NaN     NaN  1003.0      NaN
# Cabernet Franc-Cabernet Sauvignon          NaN     NaN     1.0      NaN
# Cabernet Franc-Malbec                      NaN     NaN     NaN      NaN
# Cabernet Sauvignon                         NaN     2.0  7315.0      1.0
# Cabernet Sauvignon-Cabernet Franc          NaN     NaN    12.0      NaN
# Cabernet Sauvignon-Malbec                  NaN     NaN     3.0      NaN
# Cabernet Sauvignon-Merlot                  NaN     1.0    37.0      NaN
# Cabernet Sauvignon-Shiraz                  NaN     NaN     1.0      NaN
# Cabernet Sauvignon-Syrah                   NaN     NaN    66.0      NaN
# Cabernet-Malbec                            NaN     NaN     NaN      NaN
# Cabernet-Syrah                             NaN     NaN     6.0      NaN
# Champagne Blend                            NaN     NaN    98.0      NaN
# Chardonnay                                 NaN     1.0  6801.0      1.0
# Chardonnay-Sauvignon                       NaN     NaN     NaN      NaN
# Chardonnay-Semillon                        NaN     NaN     3.0      NaN
# Chardonnay-Viognier                        NaN     NaN     8.0      NaN
# Chenin Blanc                               NaN     NaN   122.0      NaN
# Chenin Blanc-Chardonnay                    NaN     NaN     NaN      NaN
# Gewürztraminer                             NaN     NaN   406.0      NaN
# Malbec                                     NaN     NaN   537.0      NaN
# Malbec Blend                               NaN     NaN     NaN      NaN
# Malbec-Bonarda                             NaN     NaN     NaN      NaN
# Malbec-Cabernet                            NaN     NaN     NaN      NaN
# Malbec-Cabernet Franc                      NaN     NaN     NaN      NaN
# Malbec-Cabernet Sauvignon                  NaN     NaN     1.0      NaN
# ...                                        ...     ...     ...      ...
# Pinot Gris-Gewürztraminer                  NaN     NaN     1.0      NaN
# Pinot-Chardonnay                           NaN     NaN     6.0      NaN
# Piquepoul Blanc                            NaN     NaN     1.0      NaN
# Riesling-Chardonnay                        NaN     NaN     1.0      NaN
# Roussanne-Grenache Blanc                   NaN     NaN     1.0      NaN
# Roussanne-Viognier                         NaN     NaN    13.0      NaN
# Sangiovese Cabernet                        NaN     NaN     4.0      NaN
# Sangiovese-Cabernet Sauvignon              NaN     NaN     6.0      NaN
# Sangiovese-Syrah                           NaN     NaN     5.0      NaN
# Sauvignon Musqué                           NaN     NaN     1.0      NaN
# Seyval Blanc                               NaN     NaN    16.0      NaN
# Siegerrebe                                 NaN     NaN     1.0      NaN
# Souzao                                     NaN     NaN     3.0      NaN
# St. Vincent                                NaN     NaN     1.0      NaN
# Symphony                                   NaN     NaN     5.0      NaN
# Syrah-Grenache-Viognier                    NaN     NaN     1.0      NaN
# Syrah-Petite Sirah                         NaN     NaN    16.0      NaN
# Tinta Amarela                              NaN     NaN     1.0      NaN
# Tinta Madeira                              NaN     NaN     1.0      NaN
# Touriga                                    NaN     NaN     3.0      NaN
# Traminette                                 NaN     NaN    10.0      NaN
# Trousseau Gris                             NaN     NaN     3.0      NaN
# Ugni Blanc                                 NaN     NaN     3.0      NaN
# Valdiguié                                  NaN     NaN     6.0      NaN
# Valvin Muscat                              NaN     NaN     1.0      NaN
# Vignoles                                   NaN     NaN    11.0      NaN
# Viognier-Gewürztraminer                    NaN     NaN     2.0      NaN
# Viognier-Roussanne                         NaN     NaN     7.0      NaN
# Viognier-Valdiguié                         NaN     NaN     1.0      NaN
# Tempranillo-Tannat                         NaN     NaN     NaN      NaN
#
# country                            Uruguay
# variety
# Barbera                                NaN
# Bonarda                                NaN
# Bordeaux-style Red Blend               NaN
# Bordeaux-style White Blend             NaN
# Cabernet Blend                         NaN
# Cabernet Franc                         2.0
# Cabernet Franc-Cabernet Sauvignon      NaN
# Cabernet Franc-Malbec                  NaN
# Cabernet Sauvignon                     2.0
# Cabernet Sauvignon-Cabernet Franc      NaN
# Cabernet Sauvignon-Malbec              NaN
# Cabernet Sauvignon-Merlot              NaN
# Cabernet Sauvignon-Shiraz              NaN
# Cabernet Sauvignon-Syrah               NaN
# Cabernet-Malbec                        NaN
# Cabernet-Syrah                         NaN
# Champagne Blend                        NaN
# Chardonnay                             3.0
# Chardonnay-Sauvignon                   NaN
# Chardonnay-Semillon                    NaN
# Chardonnay-Viognier                    NaN
# Chenin Blanc                           NaN
# Chenin Blanc-Chardonnay                NaN
# Gewürztraminer                         NaN
# Malbec                                 2.0
# Malbec Blend                           NaN
# Malbec-Bonarda                         NaN
# Malbec-Cabernet                        NaN
# Malbec-Cabernet Franc                  NaN
# Malbec-Cabernet Sauvignon              NaN
# ...                                    ...
# Pinot Gris-Gewürztraminer              NaN
# Pinot-Chardonnay                       NaN
# Piquepoul Blanc                        NaN
# Riesling-Chardonnay                    NaN
# Roussanne-Grenache Blanc               NaN
# Roussanne-Viognier                     NaN
# Sangiovese Cabernet                    NaN
# Sangiovese-Cabernet Sauvignon          NaN
# Sangiovese-Syrah                       NaN
# Sauvignon Musqué                       NaN
# Seyval Blanc                           NaN
# Siegerrebe                             NaN
# Souzao                                 NaN
# St. Vincent                            NaN
# Symphony                               NaN
# Syrah-Grenache-Viognier                NaN
# Syrah-Petite Sirah                     NaN
# Tinta Amarela                          NaN
# Tinta Madeira                          NaN
# Touriga                                NaN
# Traminette                             NaN
# Trousseau Gris                         NaN
# Ugni Blanc                             NaN
# Valdiguié                              NaN
# Valvin Muscat                          NaN
# Vignoles                               NaN
# Viognier-Gewürztraminer                NaN
# Viognier-Roussanne                     NaN
# Viognier-Valdiguié                     NaN
# Tempranillo-Tannat                     1.0
#
# [701 rows x 43 columns]

# %% [markdown]
# ### ***EXERCISE 5.4***
# Create the equivalent of the following using only `pivot_table` and `stack/unstack`:
# ```python
# df.groupby(['country', 'variety'])['points'].mean()
# ```
#
# **HINT** To get rid of `NaN` values, add `.dropna()` at the end

# %%
# insert solution here
