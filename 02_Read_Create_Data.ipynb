# %% [markdown]
# ## Importing the library

# %%
import pandas as pd

# %% [markdown]
# ## Reading in data
# To load data into python use pandas's ```read_..``` methods. There are plenty of read methods for different file formats.
#
# For example, loading data from excel..
# ```python
# excel_file = pd.ExcelFile('path_to_excel.xlsx')
# df = pd.read_excel(excel_file, 'Sheet1')
# ```
# for other files try typing ```pd.read_``` and then hit the \<tab\> key

# %% [markdown]
# **NOTE**: be careful when using the `\` (backslash) as path separator (default in Windows), as it is used to "escape" characters to give them new meaning, e.g. `\n` means new line.
# If you need to use backslash, put a 'r' in front of the string to have python read it "raw".

# %%
pd.read_json(r'data\wine-reviews\winemag-data-130k-v2_tiny.json')
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# 10         US  Soft, supple plum envelopes an oaky structure ...
# 100        US  Fresh apple, lemon and pear flavors are accent...
# 101        US  Dusty mineral, smoke and struck flint lend a s...
# 102        US  Intensely smoky tones of struck flint and ash ...
# 103     Chile  A bright nose with green apple and citric arom...
# 104     Italy  Made with 65% Sangiovese, 20% Merlot and 15% C...
# 105     Italy  Made predominantly with Trebbiano and Malvasia...
# 106     Italy  A blend of Cabernet Sauvignon, Merlot, Caberne...
# 107     Italy  Aromas of yellow stone fruit, white spring flo...
# 108        US  Lots of spearmint, coyote mint, hot licorice, ...
# 109     Italy  An easy-drinking blend of Merlot, Sangiovese a...
# 11     France  This is a dry wine, very spicy, with a tight, ...
# 110    France  Produced from cru vines at the base of Mount B...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                        Avidagos      87   15.0              Douro
# 10                 Mountain Cuvée      87   19.0         California
# 100                          None      88   18.0           New York
# 101              Red Oak Vineyard      87   20.0           New York
# 102           Yellow Dog Vineyard      87   20.0           New York
# 103  Single Vineyard Falaris Hill      87   18.0       Leyda Valley
# 104                        Nativo      87   16.0            Tuscany
# 105                Villa Antinori      87   14.0            Tuscany
# 106                   Castiglioni      87   30.0            Tuscany
# 107          Ammiraglia Massovivo      87   18.0            Tuscany
# 108                   J.D. Hurley      87   26.0         California
# 109                      Le Volte      87   30.0            Tuscany
# 11                           None      87   30.0             Alsace
# 110                Les Quartelets      87   23.0         Beaujolais
#
#                region_1       region_2         taster_name  \
# 0                  Etna           None       Kerin O’Keefe
# 1                  None           None          Roger Voss
# 10          Napa Valley           Napa      Virginie Boone
# 100        Finger Lakes   Finger Lakes  Anna Lee C. Iijima
# 101        Finger Lakes   Finger Lakes  Anna Lee C. Iijima
# 102        Finger Lakes   Finger Lakes  Anna Lee C. Iijima
# 103                None           None   Michael Schachner
# 104             Toscana           None       Kerin O’Keefe
# 105             Toscana           None       Kerin O’Keefe
# 106             Toscana           None       Kerin O’Keefe
# 107             Toscana           None       Kerin O’Keefe
# 108  Santa Clara Valley  Central Coast       Matt Kettmann
# 109             Toscana           None       Kerin O’Keefe
# 11               Alsace           None          Roger Voss
# 110            Brouilly           None          Roger Voss
#
#     taster_twitter_handle                                              title  \
# 0            @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1              @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 10                @vboone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 100                  None             Ventosa 2015 Pinot Gris (Finger Lakes)
# 101                  None  Lamoreaux Landing 2014 Red Oak Vineyard Riesli...
# 102                  None  Lamoreaux Landing 2014 Yellow Dog Vineyard Rie...
# 103           @wineschach  Leyda 2015 Single Vineyard Falaris Hill Chardo...
# 104          @kerinokeefe             Madonna Alta 2014 Nativo Red (Toscana)
# 105          @kerinokeefe  Marchesi Antinori 2015 Villa Antinori White (T...
# 106          @kerinokeefe  Marchesi de' Frescobaldi 2014 Castiglioni Red ...
# 107          @kerinokeefe  Marchesi de' Frescobaldi 2015 Ammiraglia Masso...
# 108         @mattkettmann  Martin Ranch 2014 J.D. Hurley Zinfandel (Santa...
# 109          @kerinokeefe              Ornellaia 2014 Le Volte Red (Toscana)
# 11             @vossroger            Leon Beyer 2012 Gewurztraminer (Alsace)
# 110            @vossroger     Pardon et Fils 2015 Les Quartelets  (Brouilly)
#
#                 variety                    winery
# 0           White Blend                   Nicosia
# 1        Portuguese Red       Quinta dos Avidagos
# 10   Cabernet Sauvignon        Kirkland Signature
# 100          Pinot Gris                   Ventosa
# 101            Riesling         Lamoreaux Landing
# 102            Riesling         Lamoreaux Landing
# 103          Chardonnay                     Leyda
# 104           Red Blend              Madonna Alta
# 105         White Blend         Marchesi Antinori
# 106           Red Blend  Marchesi de' Frescobaldi
# 107          Vermentino  Marchesi de' Frescobaldi
# 108           Zinfandel              Martin Ranch
# 109           Red Blend                 Ornellaia
# 11       Gewürztraminer                Leon Beyer
# 110               Gamay            Pardon et Fils

# %% [markdown]
# ### Additional options
# All the read methods have additional useful options.
#
# The main ones for `read_csv` (some of which are in common with other `read_..` methods):
# - `sep`: defines the type of column separator
# - `index_col`: defines which column should be read as the index (row label)
# - `usecols`: allows reading only a subset of the columns
# - `skiprows` and `skipfooter`: allows ignoring of initial/final rows
# - `nrows`: allows reading of a limited amount of rows
# - `na_values`: defines the values to be treated as null
# - `parse_dates`: defines the columns that contain dates to be parsed
# - `dayfirst`: defines that the day comes before the month in the date to be parsed
# - `thousands`: defines the thousands numeric separator
# - `decimal`: defines the decimal numeric separator
# - `encoding`: defines the type of encoding to be used, default utf-8.
#
# for more information consult the corresponding [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).
#
# **TIP**: if you get a `UnicodeDecodeError: 'utf-8' codec` error, try adding `encoding='latin'` to the read options, that usually solves the issue.

# %%
pd.read_csv(
    'data/wine-reviews/winemag-data-130k-v2.csv',
    usecols=['wine_id', 'country', 'designation', 'price'],
    index_col='wine_id',
    nrows=5,
)
# Out:
#           country                         designation  price
# wine_id
# 0           Italy                        Vulkà Bianco    NaN
# 1        Portugal                            Avidagos   15.0
# 2              US                                 NaN   14.0
# 3              US                Reserve Late Harvest   13.0
# 4              US  Vintner's Reserve Wild Child Block   65.0

# %% [markdown]
# ### ***EXERCISE 2.1***
# Using the pandas documentation, find a way to read the file `data/wine-reviews/exercise_2.1.txt` in the following way:
# - read the file as tab-separated
# - parse the date in the `date of rating` column, in day/month format
# - set `country` as the index
# - skip the 3rd and 4th rows

# %%
# insert solution here

# %% [markdown]
# # Creating Data
# In order to creating a pd.DataFrame from data we have to follow the contructor specifications.
#
# In general they can be created using:
# - dictionary
# - iterable (np.array, list, pd.Series..)

# %%
# using dictionary
data = {'Name': ['Bob', 'Mary'], 'Cats':[2,0], 'Dogs':[1,2]}

pd.DataFrame(data)
# Out:
#    Name  Cats  Dogs
# 0   Bob     2     1
# 1  Mary     0     2

# %%
# using 2D iterable
data = [['Bob', 2, 1], ['Mary', 0, 2]]
labels = ['Name','Cats','Dogs'] 

pd.DataFrame(data, columns=labels)
# Out:
#    Name  Cats  Dogs
# 0   Bob     2     1
# 1  Mary     0     2

# %% [markdown]
# ### ***EXERCISE 2.2***
# Create a DataFrame like the following:
#
# |    	| r   	| g   	| b  	| hex     	|
# |--------	|-----	|-----	|----	|---------	|
# | blue   	| 0   	| 0   	| 1  	| #0000ff 	|
# | olive  	| 85  	| 107 	| 47 	| #556B2F 	|
# | sienna 	| 160 	| 82  	| 45 	| #A0522D 	|

# %%
# insert solution here
